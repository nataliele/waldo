# %%
# %cd drive/'My Drive'/'Colab Notebooks'
# Out:
# /content/drive/My Drive/Colab Notebooks

# %%
# !git clone https://github.com/pjreddie/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 5904, done.
# remote: Total 5904 (delta 0), reused 0 (delta 0), pack-reused 5904
# Receiving objects: 100% (5904/5904), 6.17 MiB | 2.10 MiB/s, done.
# Resolving deltas: 100% (3922/3922), done.
# Checking out files: 100% (979/979), done.

# %%
# %cd darknet
# Out:
# /content/drive/My Drive/Colab Notebooks/darknet

# %%
# !make
# Out:
# make: Nothing to be done for 'all'.

# %%
# !wget https://pjreddie.com/media/files/yolov2.weights
# Out:
# --2020-05-21 01:09:45--  https://pjreddie.com/media/files/yolov2.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 203934260 (194M) [application/octet-stream]
# Saving to: ‘yolov2.weights’
#
# yolov2.weights      100%[===================>] 194.49M   433KB/s    in 6m 17s
#
# 2020-05-21 01:16:03 (528 KB/s) - ‘yolov2.weights’ saved [203934260/203934260]

# %%
# !wget https://pjreddie.com/media/files/darknet19_448.conv.23
# Out:
# --2020-05-21 01:18:51--  https://pjreddie.com/media/files/darknet19_448.conv.23
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 79327120 (76M) [application/octet-stream]
# Saving to: ‘darknet19_448.conv.23’
#
# darknet19_448.conv. 100%[===================>]  75.65M   499KB/s    in 1m 57s
#
# 2020-05-21 01:20:49 (662 KB/s) - ‘darknet19_448.conv.23’ saved [79327120/79327120]

# %%
# To give yourself execute permission for the file containing 
# the script
# !chmod u+rwx darknet

# %%
# !./darknet detect cfg/yolov2.cfg yolov2.weights data/dog.jpg
# Out:
# layer     filters    size              input                output
#     0 conv     32  3 x 3 / 1   608 x 608 x   3   ->   608 x 608 x  32  0.639 BFLOPs
#     1 max          2 x 2 / 2   608 x 608 x  32   ->   304 x 304 x  32
#     2 conv     64  3 x 3 / 1   304 x 304 x  32   ->   304 x 304 x  64  3.407 BFLOPs
#     3 max          2 x 2 / 2   304 x 304 x  64   ->   152 x 152 x  64
#     4 conv    128  3 x 3 / 1   152 x 152 x  64   ->   152 x 152 x 128  3.407 BFLOPs
#     5 conv     64  1 x 1 / 1   152 x 152 x 128   ->   152 x 152 x  64  0.379 BFLOPs
#     6 conv    128  3 x 3 / 1   152 x 152 x  64   ->   152 x 152 x 128  3.407 BFLOPs
#     7 max          2 x 2 / 2   152 x 152 x 128   ->    76 x  76 x 128
#     8 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256  3.407 BFLOPs
#     9 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128  0.379 BFLOPs
#    10 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256  3.407 BFLOPs
# ...

# %%
# !python data/waldo_yolo2/process.py

# %%
# %%writefile cfg/obj_waldo_yolo2.data
# classes= 1
# train  = data/waldo_yolo2/train.txt
# valid  = data/waldo_yolo2/test.txt
# names = cfg/obj.names
# backup = backup_waldo_yolo2/
# Out:
# Writing cfg/obj_waldo_yolo2.data

# %%
# %%writefile cfg/obj.names
# waldo

# %%
# !python data/preprocess_img.py
# Out:
# /content/drive/My Drive/Colab Notebooks/darknet

# %%
# !./darknet detector train cfg/obj_waldo_yolo2.data cfg/yolov2-waldo.cfg darknet19_448.conv.23 | tee logyolo2.txt
# Out:
# Streaming output truncated to the last 5000 lines.
# Region Avg IOU: 0.741055, Class: 1.000000, Obj: 0.635710, No Obj: 0.005312, Avg Recall: 0.875000,  count: 8
# Region Avg IOU: 0.676662, Class: 1.000000, Obj: 0.690737, No Obj: 0.005696, Avg Recall: 1.000000,  count: 8
# 983: 2.131219, 2.083816 avg, 0.000934 rate, 3.896419 seconds, 31456 images
# Loaded: 0.000068 seconds
# Region Avg IOU: 0.744371, Class: 1.000000, Obj: 0.626869, No Obj: 0.005285, Avg Recall: 1.000000,  count: 8
# Region Avg IOU: 0.714897, Class: 1.000000, Obj: 0.578636, No Obj: 0.005055, Avg Recall: 1.000000,  count: 8
# Region Avg IOU: 0.672110, Class: 1.000000, Obj: 0.610581, No Obj: 0.005944, Avg Recall: 0.750000,  count: 8
# Region Avg IOU: 0.664048, Class: 1.000000, Obj: 0.666016, No Obj: 0.006894, Avg Recall: 1.000000,  count: 8
# 984: 1.356807, 2.011115 avg, 0.000938 rate, 3.890047 seconds, 31488 images
# Loaded: 0.000061 seconds
# ...

# %%
# !./darknet detector train cfg/obj_waldo_yolo2.data cfg/yolov2-waldo.cfg backup_waldo_yolo2/yolov2-waldo_1600.weights | tee logyolo2_1.txt
# Out:
# Streaming output truncated to the last 5000 lines.
# Loaded: 0.000051 seconds
# Region Avg IOU: 0.895102, Class: 1.000000, Obj: 0.891249, No Obj: 0.001252, Avg Recall: 1.000000,  count: 8
# Region Avg IOU: 0.891021, Class: 1.000000, Obj: 0.907967, No Obj: 0.001284, Avg Recall: 1.000000,  count: 8
# Region Avg IOU: 0.890858, Class: 1.000000, Obj: 0.898351, No Obj: 0.001466, Avg Recall: 1.000000,  count: 8
# Region Avg IOU: 0.908304, Class: 1.000000, Obj: 0.892775, No Obj: 0.001454, Avg Recall: 1.000000,  count: 8
# 6224: 0.060336, 0.081057 avg, 0.001000 rate, 1.424853 seconds, 199168 images
# Loaded: 0.000056 seconds
# Region Avg IOU: 0.919210, Class: 1.000000, Obj: 0.897534, No Obj: 0.001428, Avg Recall: 1.000000,  count: 8
# Region Avg IOU: 0.894482, Class: 1.000000, Obj: 0.893399, No Obj: 0.001246, Avg Recall: 1.000000,  count: 8
# Region Avg IOU: 0.912979, Class: 1.000000, Obj: 0.887531, No Obj: 0.001294, Avg Recall: 1.000000,  count: 8
# ...

# %%
# !python scripts/log_parser.py --source-dir ./ --save-dir ./ --log-file logyolo2.txt

# %%
# !python scripts/log_parser.py --source-dir ./ --save-dir ./ --log-file logyolo2_1.txt

# %%
# !./darknet detector test cfg/obj_waldo_yolo2.data cfg/yolov2-waldo.cfg backup_waldo_yolo2/yolov2-waldo_3000.weights data/waldo_yolo2/book1_s11_512_0.jpg
# !./darknet detector test cfg/obj_waldo_yolo2.data cfg/yolov2-waldo.cfg backup_waldo_yolo2/yolov2-waldo_3000.weights data/waldo_yolo2/book1_s6_256_256.jpg
# !./darknet detector test cfg/obj_waldo_yolo2.data cfg/yolov2-waldo.cfg backup_waldo_yolo2/yolov2-waldo_3000.weights data/waldo_yolo2/book1_s7_256_256.jpg

# %%
# !python test_img.py data/waldo_test/test3.jpg
# Out:
# /content/drive/My Drive/Colab Notebooks/darknet
# layer     filters    size              input                output
#     0 conv     32  3 x 3 / 1   416 x 416 x   3   ->   416 x 416 x  32  0.299 BFLOPs
#     1 max          2 x 2 / 2   416 x 416 x  32   ->   208 x 208 x  32
#     2 conv     64  3 x 3 / 1   208 x 208 x  32   ->   208 x 208 x  64  1.595 BFLOPs
#     3 max          2 x 2 / 2   208 x 208 x  64   ->   104 x 104 x  64
#     4 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128  1.595 BFLOPs
#     5 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64  0.177 BFLOPs
#     6 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128  1.595 BFLOPs
#     7 max          2 x 2 / 2   104 x 104 x 128   ->    52 x  52 x 128
#     8 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256  1.595 BFLOPs
#     9 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128  0.177 BFLOPs
# ...
